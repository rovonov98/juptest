# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению. Сессия № 2
# </center>
# Автор материала: программист-исследователь Mail.ru Group, старший преподаватель Факультета Компьютерных Наук ВШЭ Юрий Кашницкий. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Тема 3. Обучение с учителем. Методы классификации
# ## <center>Практика. Дерево решений в задаче предсказания выживания пассажиров "Титаника". Решение

# %% [markdown]
# **Заполните код в клетках и выберите ответы в [веб-форме](https://goo.gl/TBwVhQ).**
#
# **<a href="https://www.kaggle.com/c/titanic">Соревнование</a> Kaggle "Titanic: Machine Learning from Disaster".**

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import Image

# %% [markdown]
# **Функция для формирования csv-файла посылки на Kaggle:**

# %%
def write_to_submission_file(predicted_labels, out_file, train_num=891,
                    target='Survived', index_label="PassengerId"):
    # turn predictions into data frame and save as csv file
    predicted_df = pd.DataFrame(predicted_labels,
                                index = np.arange(train_num + 1,
                                                  train_num + 1 +
                                                  predicted_labels.shape[0]),
                                columns=[target])
    predicted_df.to_csv(out_file, index_label=index_label)
# write_to_submission_file

# %% [markdown]
# **Считываем обучающую и тестовую выборки.**

# %%
train_df = pd.read_csv("titanic_train.csv") 
test_df = pd.read_csv("titanic_test.csv") 
print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# (891, 12)
# (418, 11)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
y = train_df['Survived']

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
test_df.describe(include='all')
# Out:
#         PassengerId      Pclass                         Name   Sex  \
# count    418.000000  418.000000                          418   418
# unique          NaN         NaN                          418     2
# top             NaN         NaN  Ryerson, Master. John Borie  male
# freq            NaN         NaN                            1   266
# mean    1100.500000    2.265550                          NaN   NaN
# std      120.810458    0.841838                          NaN   NaN
# min      892.000000    1.000000                          NaN   NaN
# 25%      996.250000    1.000000                          NaN   NaN
# 50%     1100.500000    3.000000                          NaN   NaN
# 75%     1204.750000    3.000000                          NaN   NaN
# max     1309.000000    3.000000                          NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# unique         NaN         NaN         NaN       363         NaN
# top            NaN         NaN         NaN  PC 17608         NaN
# freq           NaN         NaN         NaN         5         NaN
# mean     30.272590    0.447368    0.392344       NaN   35.627188
# std      14.181209    0.896760    0.981429       NaN   55.907576
# min       0.170000    0.000000    0.000000       NaN    0.000000
# 25%      21.000000    0.000000    0.000000       NaN    7.895800
# 50%      27.000000    0.000000    0.000000       NaN   14.454200
# 75%      39.000000    1.000000    0.000000       NaN   31.500000
# max      76.000000    8.000000    9.000000       NaN  512.329200
#
#                   Cabin Embarked
# count                91      418
# unique               76        3
# top     B57 B59 B63 B66        S
# freq                  3      270
# mean                NaN      NaN
# std                 NaN      NaN
# min                 NaN      NaN
# 25%                 NaN      NaN
# 50%                 NaN      NaN
# 75%                 NaN      NaN
# max                 NaN      NaN

# %% [markdown]
# **Заполним пропуски медианными значениями.**

# %%
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
test_df['Age'].fillna(train_df['Age'].median(), inplace=True)
train_df['Embarked'].fillna('S', inplace=True)
test_df['Fare'].fillna(train_df['Fare'].median(), inplace=True)

# %% [markdown]
# **Кодируем категориальные признаки `Pclass`, `Sex`, `SibSp`, `Parch` и `Embarked` с помощью техники One-Hot-Encoding.**

# %%
train_df = pd.concat([train_df, pd.get_dummies(train_df['Pclass'], 
                                               prefix="PClass"),
                      pd.get_dummies(train_df['Sex'], prefix="Sex"),
                      pd.get_dummies(train_df['SibSp'], prefix="SibSp"),
                      pd.get_dummies(train_df['Parch'], prefix="Parch"),
                     pd.get_dummies(train_df['Embarked'], prefix="Embarked")],
                     axis=1)
test_df = pd.concat([test_df, pd.get_dummies(test_df['Pclass'], 
                                             prefix="PClass"),
                      pd.get_dummies(test_df['Sex'], prefix="Sex"),
                      pd.get_dummies(test_df['SibSp'], prefix="SibSp"),
                      pd.get_dummies(test_df['Parch'], prefix="Parch"),
                    pd.get_dummies(test_df['Embarked'], prefix="Embarked")],
                     axis=1)

# %%
train_df.drop(['Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 
               'Parch', 'Ticket', 'Cabin', 'Embarked', 'PassengerId'], 
              axis=1, inplace=True)
test_df.drop(['Pclass', 'Name', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked', 'PassengerId'], 
             axis=1, inplace=True)

# %% [markdown]
# **В тестовой выборке появляется новое значение Parch = 9, которого нет в обучающей выборке. Проигнорируем его.**

# %%
train_df.shape, test_df.shape
# Out:
# ((891, 24), (418, 25))

# %%
set(test_df.columns) - set(train_df.columns)
# Out:
# {'Parch_9'}

# %%
test_df.drop(['Parch_9'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#     Age     Fare  PClass_1  PClass_2  PClass_3  Sex_female  Sex_male  SibSp_0  \
# 0  22.0   7.2500     False     False      True       False      True    False
# 1  38.0  71.2833      True     False     False        True     False    False
# 2  26.0   7.9250     False     False      True        True     False     True
# 3  35.0  53.1000      True     False     False        True     False    False
# 4  35.0   8.0500     False     False      True       False      True     True
#
#    SibSp_1  SibSp_2  ...  Parch_0  Parch_1  Parch_2  Parch_3  Parch_4  \
# 0     True    False  ...     True    False    False    False    False
# 1     True    False  ...     True    False    False    False    False
# 2    False    False  ...     True    False    False    False    False
# 3     True    False  ...     True    False    False    False    False
# 4    False    False  ...     True    False    False    False    False
#
#    Parch_5  Parch_6  Embarked_C  Embarked_Q  Embarked_S
# 0    False    False       False       False        True
# 1    False    False        True       False       False
# 2    False    False       False       False        True
# 3    False    False       False       False        True
# 4    False    False       False       False        True
#
# [5 rows x 24 columns]

# %%
test_df.head()
# Out:
#     Age     Fare  PClass_1  PClass_2  PClass_3  Sex_female  Sex_male  SibSp_0  \
# 0  34.5   7.8292     False     False      True       False      True     True
# 1  47.0   7.0000     False     False      True        True     False    False
# 2  62.0   9.6875     False      True     False       False      True     True
# 3  27.0   8.6625     False     False      True       False      True     True
# 4  22.0  12.2875     False     False      True        True     False    False
#
#    SibSp_1  SibSp_2  ...  Parch_0  Parch_1  Parch_2  Parch_3  Parch_4  \
# 0    False    False  ...     True    False    False    False    False
# 1     True    False  ...     True    False    False    False    False
# 2    False    False  ...     True    False    False    False    False
# 3    False    False  ...     True    False    False    False    False
# 4     True    False  ...    False     True    False    False    False
#
#    Parch_5  Parch_6  Embarked_C  Embarked_Q  Embarked_S
# 0    False    False       False        True       False
# 1    False    False       False       False        True
# 2    False    False       False        True       False
# 3    False    False       False       False        True
# 4    False    False       False       False        True
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 1. Дерево решений без настройки параметров

# %% [markdown]
# **Обучите на имеющейся выборке дерево решений (`DecisionTreeClassifier`) максимальной глубины 2. Используйте параметр `random_state=17` для воспроизводимости результатов.**

# %%
tree = DecisionTreeClassifier(max_depth=3, random_state=17)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=17)

# %%
cross_val_score(tree, train_df, y, cv=5).mean()
# Out:
# 0.8080723118448307

# %% [markdown]
# **Сделайте с помощью полученной модели прогноз для тестовой выборки **

# %%
tree_grid = GridSearchCV(tree, {'max_depth': [2]}, cv = 5, n_jobs=-1)
tree_grid.fit(train_df,y)
test = tree_grid.predict(test_df)

# //tut otvet, pohodu 'test' nuzhno otpravit' v kaggle tam y_valid est'

# %%
test.mean()
# Out:
# 0.21052631578947367

# %% [markdown]
# **Сформируйте файл посылки и отправьте на Kaggle**

# %%
write_to_submission_file(test, "titanic_res.csv")

# %% [markdown]
# <font color='red'>Вопрос 1. </font> Каков результат первой посылки (дерево решений без настройки параметров) в публичном рейтинге соревнования Titanic?
# - 0.746
# - 0.756
# - 0.766
# - 0.776

# %% [markdown]
# **Отобразите дерево с помощью `export_graphviz` и `dot`.**

# %%
export_graphviz(tree_grid.best_estimator_, out_file="titanic.dot",feature_names=test_df.columns, filled=True)
# !ls -l *.png
# !dot -Tpng titanic.dot -o titanic.png
Image(filename='titanic.png')
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
# 'dot' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 4
#       2 get_ipython().system('ls -l *.png')
#       3 get_ipython().system('dot -Tpng titanic.dot -o titanic.png')
# ----> 4 Image(filename='titanic.png')
#
# File c:\Users\Nikita\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File c:\Users\Nikita\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File c:\Users\Nikita\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File c:\Users\Nikita\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: 'titanic.png'

# %% [markdown]
# <font color='red'>Вопрос 2. </font> Сколько признаков задействуются при прогнозе деревом решений глубины 2?
# - 2
# - 3
# - 4
# - 5

# %% [markdown]
# ## 2. Дерево решений с настройкой параметров

# %% [markdown]
# **Обучите на имеющейся выборке дерево решений (`DecisionTreeClassifier`). Также укажите `random_state=17`. Максимальную глубину и минимальное число элементов в листе настройте на 5-кратной кросс-валидации с помощью `GridSearchCV`.**

# %%
# tree params for grid search
tree_params2 = {'max_depth': list(range(1, 5)), 
               'min_samples_leaf': list(range(1, 5))}
tree2 = DecisionTreeClassifier(random_state=17)
grid = GridSearchCV(tree2, tree_params2, cv = 5, n_jobs=-1 )
grid.fit(train_df, y)
grid.best_params_
tree3 = DecisionTreeClassifier(max_depth=3, min_samples_leaf=3,random_state=17)
cross_val_score(tree3, train_df, y, cv = 5).mean()
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-1-e550365020d3> in <module>()
#       2 tree_params2 = {'max_depth': list(range(1, 5)),
#       3                'min_samples_leaf': list(range(1, 5)), 'max_features': list(range(1,10))}
# ----> 4 tree2 = DecisionTreeClassifier(random_state=17)
#       5 grid = GridSearchCV(tree2, tree_params2, cv = 5, n_jobs=-1 )
#       6 grid.fit(train_df, y)
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %% [markdown]
# <font color='red'>Вопрос 3. </font> Каковы лучшие параметры дерева, настроенные на кросс-валидации с помощью `GridSearchCV`?
# - max_depth=2, min_samples_leaf=1
# - max_depth=2, min_samples_leaf=4
# - max_depth=3, min_samples_leaf=2
# - max_depth=3, min_samples_leaf=3

# %% [markdown]
# <font color='red'>Вопрос 4. </font> Какой получилась средняя доля верных ответов на кросс-валидации для дерева решений с лучшим сочетанием гиперпараметров `max_depth` и `min_samples_leaf`?
# - 0.77
# - 0.79
# - 0.81
# - 0.83

# %% [markdown]
# **Сделайте с помощью полученной модели прогноз для тестовой выборки.**

# %%
tree3 = DecisionTreeClassifier(max_depth=3, min_samples_leaf=3,random_state=17)
tree_params3 = {'max_depth': [3], 
               'min_samples_leaf': [3]}
grid3 = GridSearchCV(tree3, tree_params3, cv = 5, n_jobs=-1 )
grid3.fit(train_df, y)
ans = grid3.predict(test_df)

# %% [markdown]
# **Сформируйте файл посылки и отправьте на Kaggle.**

# %%
# Ваш код здесь

# %% [markdown]
# <font color='red'>Вопрос 5. </font> Каков результат второй посылки (дерево решений с настройкой гиперпараметров) в публичном рейтинге соревнования Titanic?
# - 0.7499
# - 0.7599
# - 0.7699
# - 0.7799

# %% [markdown]
# ## Ссылки:

# %% [markdown]
#  - <a href="https://www.kaggle.com/c/titanic">Соревнование</a> Kaggle "Titanic: Machine Learning from Disaster"
#  - <a href="https://www.dataquest.io/mission/74/getting-started-with-kaggle/">Тьюториал</a> Dataquest по задаче Kaggle "Titanic: Machine Learning from Disaster"
